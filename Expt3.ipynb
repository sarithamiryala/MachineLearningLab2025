# %% [markdown]
# <a href="https://colab.research.google.com/github/sarithamiryala/MachineLearningLab2025/blob/main/Expt3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load the Iris dataset

# %%
iris = datasets.load_iris()
X = iris.data  # Features (4-dimensional)
y = iris.target  # Target labels (Setosa, Versicolor, Virginica)

# %% [markdown]
# # Standardize the features (PCA works better with standardized data)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Apply PCA to reduce dimensions from 4 to 2

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# # Convert to DataFrame for visualization

# %%
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['Target'] = y

# %% [markdown]
# # Visualize the transformed data

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue=df_pca['Target'], palette='viridis', data=df_pca, alpha=0.8)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA: Iris Dataset (4D → 2D)")
plt.legend(title="Species", labels=iris.target_names)
plt.show()

# %%
# Explained variance ratio
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("Total variance explained:", sum(pca.explained_variance_ratio_))
# Out:
# Explained variance ratio: [0.72962445 0.22850762]
# Total variance explained: 0.9581320720000166
