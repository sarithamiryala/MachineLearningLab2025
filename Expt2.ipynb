# %% [markdown]
# <a href="https://colab.research.google.com/github/sarithamiryala/MachineLearningLab2025/blob/main/Expt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing the important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# # Load California Housing dataset

# %%
california = fetch_california_housing()
df = pd.DataFrame(california.data, columns=california.feature_names)

# %% [markdown]
# # Compute the correlation matrix

# %%
correlation_matrix = df.corr()

# %% [markdown]
# # Plot the heatmap of the correlation matrix

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of California Housing Features")
plt.show()

# %% [markdown]
# # Pair plot for pairwise feature relationships

# %%
sns.pairplot(df, diag_kind="kde", corner=True)
plt.show()
